# %%
import pandas as pd

# %%
df = pd.read_csv('tamheer_2022.csv')

# %%
df.shape
# Out:
# (112615, 20)

# %%
df.head()
# Out:
#    ID جنس المتدرب مدينة المتدرب منطقة المتدرب                    تخصص المتدرب  \
# 0   1         ذكر         تيماء          تبوك                             NaN
# 1   2        انثى      ام نخيلة         الجوف  علوم الحاسب الآلي والمعلوماتية
# 2   3         ذكر       الخرخير         نجران                 الهندسة المدنية
# 3   4         ذكر       الخرخير         نجران                 الهندسة المدنية
# 4   5         ذكر       الخرخير         نجران                 الهندسة المدنية
#
#                 مؤهل المتدرب  معدل المتدرب  المعدل من  عمر المتدرب  \
# 0  البكالوريوس أو ما يعادلها          2.57        0.0           40
# 1                    دكتوراه         88.93        0.0           51
# 2                  بكالوريوس          2.05        0.0           37
# 3                  بكالوريوس          2.05        0.0           37
# 4                  بكالوريوس          2.05        0.0           37
#
#   تاريخ بداية التدريب تاريخ نهاية التدريب حالة المتدرب  \
# ...

# %%
df.tail()
# Out:
#             ID جنس المتدرب مدينة المتدرب منطقة المتدرب   تخصص المتدرب  \
# 112610  112611        انثى          ابها          عسير  نظم المعلومات
# 112611  112612        انثى          ابها          عسير  نظم المعلومات
# 112612  112613        انثى          ابها          عسير  نظم المعلومات
# 112613  112614        انثى          ابها          عسير  نظم المعلومات
# 112614  112615        انثى          ابها          عسير  نظم المعلومات
#
#        مؤهل المتدرب  معدل المتدرب  المعدل من  عمر المتدرب تاريخ بداية التدريب  \
# 112610    بكالوريوس          4.13        0.0           24                 NaN
# 112611    بكالوريوس          4.13        0.0           24                 NaN
# 112612    بكالوريوس          4.13        0.0           24                 NaN
# 112613    بكالوريوس          4.13        0.0           24                 NaN
# 112614    بكالوريوس          4.13        0.0           24                 NaN
#
#        تاريخ نهاية التدريب حالة المتدرب  \
# ...

# %%
df.dtypes
# Out:
# ID                                     int64
# جنس المتدرب                           object
# مدينة المتدرب                         object
# منطقة المتدرب                         object
# تخصص المتدرب                          object
# مؤهل المتدرب                          object
# معدل المتدرب                         float64
# المعدل من                            float64
# عمر المتدرب                            int64
# تاريخ بداية التدريب                   object
# تاريخ نهاية التدريب                   object
# حالة المتدرب                          object
# اسم الفرصه التدريبية                  object
# النشاط الاقتصادي للفرصة التدريبية     object
# مؤهل التدريب                          object
# تاريخ الانتهاء                        object
# تاريخ الانسحاب                        object
# حجم مؤسسة التدريب                     object
# النشاط الاقتصادي لمؤسسة التدريب       object
# المؤسسة التعليمية للمتدرب             object
# dtype: object

# %%
df.describe()
# Out:
#                  ID  معدل المتدرب     المعدل من    عمر المتدرب
# count  112615.00000  97855.000000  97855.000000  112615.000000
# mean    56308.00000      5.762873      1.685933      25.604156
# std     32509.29462     13.806602      2.280288       2.155375
# min         1.00000      0.000000      0.000000      24.000000
# 25%     28154.50000      2.810000      0.000000      24.000000
# 50%     56308.00000      3.330000      0.000000      25.000000
# 75%     84461.50000      4.000000      5.000000      26.000000
# max    112615.00000    100.000000      5.000000      55.000000

# %%
df.isna().sum()
# Out:
# ID                                        0
# جنس المتدرب                             243
# مدينة المتدرب                          1229
# منطقة المتدرب                          1229
# تخصص المتدرب                           6484
# مؤهل المتدرب                            199
# معدل المتدرب                          14760
# المعدل من                             14760
# عمر المتدرب                               0
# تاريخ بداية التدريب                  111014
# تاريخ نهاية التدريب                  111014
# حالة المتدرب                              0
# اسم الفرصه التدريبية                      2
# النشاط الاقتصادي للفرصة التدريبية         0
# مؤهل التدريب                              0
# تاريخ الانتهاء                            0
# تاريخ الانسحاب                       112437
# حجم مؤسسة التدريب                         0
# النشاط الاقتصادي لمؤسسة التدريب       39207
# المؤسسة التعليمية للمتدرب              6462
# dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of             ID جنس المتدرب مدينة المتدرب منطقة المتدرب  \
# 0            1         ذكر         تيماء          تبوك
# 1            2        انثى      ام نخيلة         الجوف
# 2            3         ذكر       الخرخير         نجران
# 3            4         ذكر       الخرخير         نجران
# 4            5         ذكر       الخرخير         نجران
# ...        ...         ...           ...           ...
# 112610  112611        انثى          ابها          عسير
# 112611  112612        انثى          ابها          عسير
# 112612  112613        انثى          ابها          عسير
# 112613  112614        انثى          ابها          عسير
# 112614  112615        انثى          ابها          عسير
#
#                           تخصص المتدرب               مؤهل المتدرب  \
# 0                                  NaN  البكالوريوس أو ما يعادلها
# 1       علوم الحاسب الآلي والمعلوماتية                    دكتوراه
# 2                      الهندسة المدنية                  بكالوريوس
# ...

# %%
df.isnull().mean() * 100
# Out:
# ID                                    0.000000
# جنس المتدرب                           0.215779
# مدينة المتدرب                         1.091329
# منطقة المتدرب                         1.091329
# تخصص المتدرب                          5.757670
# مؤهل المتدرب                          0.176708
# معدل المتدرب                         13.106602
# المعدل من                            13.106602
# عمر المتدرب                           0.000000
# تاريخ بداية التدريب                  98.578342
# تاريخ نهاية التدريب                  98.578342
# حالة المتدرب                          0.000000
# اسم الفرصه التدريبية                  0.001776
# النشاط الاقتصادي للفرصة التدريبية     0.000000
# مؤهل التدريب                          0.000000
# تاريخ الانتهاء                        0.000000
# تاريخ الانسحاب                       99.841939
# حجم مؤسسة التدريب                     0.000000
# النشاط الاقتصادي لمؤسسة التدريب      34.815078
# المؤسسة التعليمية للمتدرب             5.738134
# dtype: float64
